# %% [markdown]
# # Scale the temperature to induce more transitions
# In [Notes.ipynb](Notes.ipynb) we see that an initial temperature of 400 and a temperature of 2000 causes less trajectory vs wall clock time progression (`times.out`) but more action on the in-memory database. Here we scale the temperatures to see more transitions. In the nomenclature below, `t` is temperature and `it` is initial temperature.

# %%
from helpers import *
# %matplotlib inline
results = ["results-t2000it400.xml-dbfix",
           "results-t4000it400.xml-scaletemp",
           "results-t6000it400.xml-scaletemp",
           "results-t8000it400.xml-scaletemp"]

# %%
plot_times(results)

# %% [markdown]
# Lol. Nobody made any progress.

# %%
plot_dbactivity(results, dbnode='node-1')

# %%
plot_psactivity_sweep(results)
# Out:
# results-t2000it400.xml-dbfix results-t4000it400.xml-scaletemp results-t6000it400.xml-scaletemp results-t8000it400.xml-scaletemp
